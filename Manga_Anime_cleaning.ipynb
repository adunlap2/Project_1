# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy as np

# %%
manga_df = pd.read_csv(r"C:\Users\Jordan\Desktop\MAL-manga.csv", index_col='Unnamed: 0')
anime_df = pd.read_csv(r"C:\Users\Jordan\Desktop\anime_copy.csv", index_col= 'Unnamed: 0')

manga_df.head()
anime_df.head()
# Out:
#                                             Title   Rank     Type Episodes  \
# 0                               Net-juu no Susume   1568       TV       10
# 1  Neon Genesis Evangelion: The End of Evangelion     99    Movie        1
# 2                                         Templex  11445    Movie        1
# 3                                        s.CRY.ed   2248       TV       26
# 4                  Toaru Majutsu no Index-tan III   6679  Special        2
#
#                  Aired  Members  \
# 0  Oct 2017 - Dec 2017   450968
# 1  Jul 1997 - Jul 1997   883576
# 2          2015 - 2015      538
# 3  Jul 2001 - Dec 2001    81283
# 4  Dec 2018 - Apr 2019    11370
#
#                                             page_url  \
# 0  https://myanimelist.net/anime/36038/Net-juu_no...
# 1  https://myanimelist.net/anime/32/Neon_Genesis_...
# 2        https://myanimelist.net/anime/40721/Templex
# 3           https://myanimelist.net/anime/168/sCRYed
# 4  https://myanimelist.net/anime/39094/Toaru_Maju...
#
#                                            image_url  Score
# 0  https://cdn.myanimelist.net/r/100x140/images/a...   7.55
# 1  https://cdn.myanimelist.net/r/100x140/images/a...   8.55
# 2  https://cdn.myanimelist.net/r/100x140/images/a...   5.29
# 3  https://cdn.myanimelist.net/r/100x140/images/a...   7.36
# 4  https://cdn.myanimelist.net/r/100x140/images/a...   6.44

# %%
cleaned_manga = manga_df.drop(columns=["page_url", "image_url"])
cleaned_manga.head()
# Out:
#               Title   Rank      Type Volumes            Published  Members  \
# 0       City Hunter    460     Manga      35  Feb 1985 - Nov 1991    14690
# 1     Keijo!!!!!!!!   4532     Manga      18  Jul 2013 - Apr 2017    12689
# 2              Rain   1808     Manga       ?           Nov 2008 -    12021
# 3  Hidari no Futari  17377  One-shot       ?          2011 - 2011     1010
# 4      Odd Girl Out    953    Manhwa       ?           May 2015 -     4968
#
#    Score
# 0   8.16
# 1   7.31
# 2   7.67
# 3   5.95
# 4   7.90

# %%
cleaned_anime = anime_df.drop(columns=["page_url", "image_url"])
cleaned_anime.head()
# Out:
#                                             Title   Rank     Type Episodes  \
# 0                               Net-juu no Susume   1568       TV       10
# 1  Neon Genesis Evangelion: The End of Evangelion     99    Movie        1
# 2                                         Templex  11445    Movie        1
# 3                                        s.CRY.ed   2248       TV       26
# 4                  Toaru Majutsu no Index-tan III   6679  Special        2
#
#                  Aired  Members  Score
# 0  Oct 2017 - Dec 2017   450968   7.55
# 1  Jul 1997 - Jul 1997   883576   8.55
# 2          2015 - 2015      538   5.29
# 3  Jul 2001 - Dec 2001    81283   7.36
# 4  Dec 2018 - Apr 2019    11370   6.44

# %%
cleaned_manga[cleaned_manga["Volumes"]== '?']
# Out:
#                                                    Title   Rank      Type  \
# 2                                                   Rain   1808     Manga
# 3                                       Hidari no Futari  17377  One-shot
# 4                                           Odd Girl Out    953    Manhwa
# 7                                          Ruru Chouchou  13402  One-shot
# 11                                         Kiratto!☆Yell  16913  One-shot
# ...                                                  ...    ...       ...
# 17793                           Kimi wa Houkago Insomnia    109     Manga
# 17803                                       Super Lovers    717     Manga
# 17805                                      Yoru no Kouen  17791  One-shot
# 17806  Akuyaku Reijou desu ga Kouryaku Taishou no You...  10635     Manga
# 17809                Arakure Ojousama wa Monmon Shiteiru   7569     Manga
#
#       Volumes            Published  Members  Score
# 2           ?           Nov 2008 -    12021   7.67
# 3           ?          2011 - 2011     1010   5.95
# 4           ?           May 2015 -     4968   7.90
# 7           ?  Dec 2012 - Dec 2012      457   6.64
# 11          ?          2012 - 2012      319   6.17
# ...       ...                  ...      ...    ...
# 17793       ?           May 2019 -    36829   8.55
# 17803       ?           Oct 2009 -    22933   8.01
# 17805       ?  Jun 1982 - Jun 1982      197   5.31
# 17806       ?           Dec 2020 -     1142   6.85
# 17809       ?           Nov 2018 -    11257   7.07
#
# [5175 rows x 7 columns]

# %%
cleaned_manga["Volumes"] = cleaned_manga['Volumes'].replace(['?'], "Unknown")
cleaned_manga
# Out:
#                                                    Title   Rank      Type  \
# 0                                            City Hunter    460     Manga
# 1                                          Keijo!!!!!!!!   4532     Manga
# 2                                                   Rain   1808     Manga
# 3                                       Hidari no Futari  17377  One-shot
# 4                                           Odd Girl Out    953    Manhwa
# ...                                                  ...    ...       ...
# 17806  Akuyaku Reijou desu ga Kouryaku Taishou no You...  10635     Manga
# 17807                                             Hakuji   5720     Manga
# 17808                Maouritsu Chuu-Boss Yousei Academia  15889     Manga
# 17809                Arakure Ojousama wa Monmon Shiteiru   7569     Manga
# 17810                           Tensei Ouji wa Daraketai  12899     Manga
#
#        Volumes            Published  Members  Score
# 0           35  Feb 1985 - Nov 1991    14690   8.16
# 1           18  Jul 2013 - Apr 2017    12689   7.31
# 2      Unknown           Nov 2008 -    12021   7.67
# 3      Unknown          2011 - 2011     1010   5.95
# 4      Unknown           May 2015 -     4968   7.90
# ...        ...                  ...      ...    ...
# 17806  Unknown           Dec 2020 -     1142   6.85
# 17807        2  May 2008 - Apr 2010     6103   7.21
# 17808        3  Sep 2017 - Mar 2019      696   6.38
# 17809  Unknown           Nov 2018 -    11257   7.07
# 17810        3  Jan 2018 - Mar 2020     6203   6.68
#
# [17811 rows x 7 columns]
